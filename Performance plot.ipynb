# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib
matplotlib.use('Agg')

# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = (14.0, 8.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [5, 10, 15, 20, 25]
y = [3017, 5641, 8403, 11446, 12000]

# %%
plt.plot(x, y, color="#2874A6", alpha=0.5, linewidth=3)
# plt.scatter(x, y, s=100, marker="s", color='b')
plt.xticks(x, [str(_) for _ in x], fontsize=36)
plt.yticks([_ for _ in [4000, 6000, 8000, 10000, 12000]], [_ for _ in ['4k', '6k', '8k', '10k', '12k']], fontsize=36)
plt.xlabel("Number of agents", fontsize=36)
plt.ylabel("Number of samples/sec", fontsize=36)
plt.grid(linestyle='--', alpha=0.5)

plt.bar(np.asarray(x) - 1.25, y, width=2.5, color="#5DADE2")
# for i,j in zip(x, y):
#     plt.annotate('%s' %j, xy=(i, j+100), xytext=(30,0), textcoords='offset points', horizontalalignment='right', fontsize=25)
    
plt.tight_layout()
plt.ylim([0,13000])
plt.xlim([3, 27])
plt.savefig('plot.pdf')
