# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib
matplotlib.use('Agg')

# %matplotlib inline

matplotlib.rcParams['figure.figsize'] = (15.0, 8.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [5, 10, 15, 20, 25]
y = [3017, 5641, 8403, 11446, 12000]

# %%
plt.plot(x, y, color='k', alpha=0.5)
plt.scatter(x, y, s=100, marker="s", color='k')
plt.xticks(x, [str(_) for _ in x], fontsize=20)
plt.yticks([_ for _ in [4000, 6000, 8000, 10000, 12000]], [_ for _ in ['4k', '6k', '8k', '10k', '12k']], fontsize=20)
plt.xlabel("Number of data generators", fontsize=24)
plt.ylabel("Number of examples/second", fontsize=24)
plt.grid(linestyle='--', alpha=0.5)
plt.tight_layout()
plt.savefig('plot.pdf')
